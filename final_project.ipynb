# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, auc
import numpy as np
from sklearn.svm import SVC
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('diabetes.csv')

X = data[['Glucose']]
y = data['Outcome']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB

nb_model = GaussianNB()
nb_model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn.metrics import accuracy_score

y_pred = nb_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("دقت در مودل بیز:", accuracy)
# Out:
# دقت در مودل بیز: 0.7135416666666666

# %%
nb_model = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 6))
sns.heatmap(nb_model, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Glucose', 'Outcome'], yticklabels=['Glucose', 'Outcome'])
plt.xlabel('پیش بینی شده')
plt.ylabel('واقعی')
plt.title('ماتریس درهم ریختگی')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression()
lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score

y_pred = lr_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("LogisticRegressionدقت در :", accuracy)
# Out:
# LogisticRegressionدقت در : 0.7083333333333334

# %%
lr_model = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 6))
sns.heatmap(lr_model, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Glucose', 'Outcome'], yticklabels=['Glucose', 'Outcome'])
plt.xlabel('پیش بینی شده')
plt.ylabel('واقعی')
plt.title('ماتریس درهم ریختگی')
plt.show()

# %%
from sklearn.svm import SVC

svm_model = SVC()
svm_model.fit(X_train, y_train)
# Out:
# SVC()

# %%
from sklearn.metrics import accuracy_score

y_pred = svm_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("دقت در svm:", accuracy)
# Out:
# دقت در svm: 0.71875

# %%
svm_model = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 6))
sns.heatmap(svm_model, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Glucose', 'Outcome'], yticklabels=['Glucose', 'Outcome'])
plt.xlabel('پیش بینی شده')
plt.ylabel('واقعی')
plt.title('ماتریس درهم ریختگی')
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier()
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score

y_pred = dt_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("دقت در id3:", accuracy)
# Out:
# دقت در id3: 0.6927083333333334

# %%
dt_model = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 6))
sns.heatmap(dt_model, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Glucose', 'Outcome'], yticklabels=['Glucose', 'Outcome'])
plt.xlabel('پیش بینی شده')
plt.ylabel('واقعی')
plt.title('ماتریس درهم ریختگی')
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier(n_neighbors=4)
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
y_pred = knn_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("دقت در KNN:", accuracy)
# Out:
# دقت در KNN: 0.703125

# %%
knn_model = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 6))
sns.heatmap(knn_model, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Glucose', 'Outcome'], yticklabels=['Glucose', 'Outcome'])
plt.xlabel('پیش بینی شده')
plt.ylabel('واقعی')
plt.title('ماتریس درهم ریختگی')
plt.show()
